# %%
import pandas as pd

# %%
week1 = pd.read_csv("/home/gabrielajachs/Downloads/pandas/Restaurant - Week 1 Sales.csv")
pd.set_option('display.max_rows', 50000000)
week2 = pd.read_csv("/home/gabrielajachs/Downloads/pandas/Restaurant - Week 2 Sales.csv")
customers = pd.read_csv("/home/gabrielajachs/Downloads/pandas/Restaurant - Customers.csv")
foods = pd.read_csv("/home/gabrielajachs/Downloads/pandas/Restaurant - Foods.csv")

# %%
week1.head(3)
# Out:
#    Customer ID  Food ID
# 0          537        9
# 1           97        4
# 2          658        1

# %%
week2.head(3)
# Out:
#    Customer ID  Food ID
# 0          688       10
# 1          813        7
# 2          495       10

# %%
customers.head(3)
# Out:
#    ID First Name Last Name  Gender  Company                     Occupation
# 0   1     Joseph   Perkins    Male  Dynazzy  Community Outreach Specialist
# 1   2   Jennifer   Alvarez  Female     DabZ        Senior Quality Engineer
# 2   3      Roger     Black    Male  Tagfeed              Account Executive

# %%
foods.head(3)
# Out:
#    Food ID Food Item  Price
# 0        1     Sushi   3.99
# 1        2   Burrito   9.99
# 2        3      Taco   2.99

# %%
pd.concat(objs = [week1, week2], ignore_index = True)
# Out:
#      Customer ID  Food ID
# 0            537        9
# 1             97        4
# 2            658        1
# 3            202        2
# 4            155        9
# 5            213        8
# 6            600        1
# 7            503        5
# 8             71        3
# 9            174        3
# 10           961        9
# 11           966        5
# 12           641        4
# 13           288        2
# 14           149        4
# 15           954        2
# 16           147        9
# 17           155        1
# 18           550        6
# 19           101        7
# 20           549        6
# 21            75        6
# 22            78        7
# 23           514        5
# 24           833        7
# 25           329        8
# 26           586       10
# 27           341        1
# 28           519       10
# 29           680        9
# 30           419        7
# 31            20        1
# 32           822        6
# 33           226       10
# ...

# %%
sales = pd.concat(objs = [week1, week2], keys = ["Week 1","Week 2"])

# %%
sales.head(3)
# Out:
#           Customer ID  Food ID
# Week 1 0          537        9
#        1           97        4
#        2          658        1

# %%
week1[week1["Customer ID"] == 155]
# Out:
#     Customer ID  Food ID
# 4           155        9
# 17          155        1

# %%
week2[week2["Customer ID"] == 155]
# Out:
#      Customer ID  Food ID
# 208          155        3

# %%
week1.merge(week2, how = "inner", on = "Customer ID", suffixes = [" - Week 1", " - Week 2"])
# Out:
#     Customer ID  Food ID - Week 1  Food ID - Week 2
# 0           537                 9                 5
# 1           155                 9                 3
# 2           155                 1                 3
# 3           503                 5                 8
# 4           503                 5                 9
# 5           550                 6                 7
# 6           101                 7                 4
# 7            75                 6                 4
# 8            77                 1                 7
# 9            77                 9                 7
# 10           77                 2                 7
# 11           77                 9                 7
# 12          628                 4                 7
# 13          798                 9                 5
# 14          798                 1                 5
# 15          462                 3                 8
# 16          304                 3                 3
# ...

# %%
week1.merge(week2, how = "inner", on = ["Customer ID", "Food ID"])
# Out:
#    Customer ID  Food ID
# 0          304        3
# 1          540        3
# 2          937       10
# 3          233        3
# 4           21        4
# 5           21        4
# 6          922        1
# 7          578        5
# 8          578        5

# %%
merged = week1.merge(week2, how = "outer", on = "Customer ID", suffixes = [" - Week 1", " - Week 2"],
           indicator = True)

# %%
merged["_merge"].value_counts()
# Out:
# right_only    197
# left_only     195
# both           62
# Name: _merge, dtype: int64

# %%
mask = merged["_merge"].isin(["right_only", "left_only"])
merged[mask]
# Out:
#      Customer ID  Food ID - Week 1  Food ID - Week 2      _merge
# 1             97               4.0               NaN   left_only
# 2            658               1.0               NaN   left_only
# 3            202               2.0               NaN   left_only
# 6            213               8.0               NaN   left_only
# 7            600               1.0               NaN   left_only
# 10            71               3.0               NaN   left_only
# 11            71               8.0               NaN   left_only
# 12           174               3.0               NaN   left_only
# 13           961               9.0               NaN   left_only
# 14           966               5.0               NaN   left_only
# 15           641               4.0               NaN   left_only
# 16           288               2.0               NaN   left_only
# 17           149               4.0               NaN   left_only
# ...

# %%
week1 = week1.merge(foods, how = "left", on = "Food ID", sort = True)
week1.head()
# Out:
#    Customer ID  Food ID Food Item  Price
# 0          658        1     Sushi   3.99
# 1          600        1     Sushi   3.99
# 2          155        1     Sushi   3.99
# 3          341        1     Sushi   3.99
# 4           20        1     Sushi   3.99

# %%
week1 = pd.read_csv("/home/gabrielajachs/Downloads/pandas/Restaurant - Week 1 Sales.csv")
pd.set_option('display.max_rows', 50000000)
week2 = pd.read_csv("/home/gabrielajachs/Downloads/pandas/Restaurant - Week 2 Sales.csv")
customers = pd.read_csv("/home/gabrielajachs/Downloads/pandas/Restaurant - Customers.csv")
foods = pd.read_csv("/home/gabrielajachs/Downloads/pandas/Restaurant - Foods.csv")

# %%
week2.head()
# Out:
#    Customer ID  Food ID
# 0          688       10
# 1          813        7
# 2          495       10
# 3          189        5
# 4          267        3

# %%
customers.head()
# Out:
#    ID First Name Last Name  Gender  Company                     Occupation
# 0   1     Joseph   Perkins    Male  Dynazzy  Community Outreach Specialist
# 1   2   Jennifer   Alvarez  Female     DabZ        Senior Quality Engineer
# 2   3      Roger     Black    Male  Tagfeed              Account Executive
# 3   4     Steven     Evans    Male     Fatz               Registered Nurse
# 4   5       Judy  Morrison  Female  Demivee                Legal Assistant

# %%
week2.merge(customers, how = "left", left_on = "Customer ID", right_on = "ID", sort = True).drop("ID", axis = "columns")
# Out:
#      Customer ID  Food ID   First Name   Last Name  Gender        Company  \
# 0              8        6      Frances       Adams  Female       Dabshots
# 1             13        2         Ruth     Alvarez  Female    Twitterlist
# 2             21        4       Albert       Burns    Male      Rhynoodle
# 3             24        8        Donna      Thomas  Female        Jaxbean
# 4             27        4      Jessica     Bennett  Female  Twitternation
# 5             30        4       Pamela       Hicks  Female          Ntags
# 6             35        8       Nicole     Chapman  Female        Pixonyx
# 7             39       10       Teresa    Harrison  Female            Oba
# 8             45        8         Earl    Marshall    Male          Agivu
# 9             46        6         Adam        Cole    Male          Trupe
# 10            54        8       Amanda       Berry  Female        Jaxspan
# 11            55        9        Ralph        Ford    Male     Browsezoom
# ...

# %%
customers.head()
# Out:
#    ID First Name Last Name  Gender  Company                     Occupation
# 0   1     Joseph   Perkins    Male  Dynazzy  Community Outreach Specialist
# 1   2   Jennifer   Alvarez  Female     DabZ        Senior Quality Engineer
# 2   3      Roger     Black    Male  Tagfeed              Account Executive
# 3   4     Steven     Evans    Male     Fatz               Registered Nurse
# 4   5       Judy  Morrison  Female  Demivee                Legal Assistant

# %%
week1 = pd.read_csv("/home/gabrielajachs/Downloads/pandas/Restaurant - Week 1 Sales.csv")
pd.set_option('display.max_rows', 50000000)
week2 = pd.read_csv("/home/gabrielajachs/Downloads/pandas/Restaurant - Week 2 Sales.csv")
customers = pd.read_csv("/home/gabrielajachs/Downloads/pandas/Restaurant - Customers.csv", index_col = "ID")
foods = pd.read_csv("/home/gabrielajachs/Downloads/pandas/Restaurant - Foods.csv", index_col = "Food ID")

# %%
foods.head()
# Out:
#           Food Item  Price
# Food ID
# 1             Sushi   3.99
# 2           Burrito   9.99
# 3              Taco   2.99
# 4        Quesadilla   4.25
# 5             Pizza   2.49

# %%
sales = week1.merge(customers, how =  "left", left_on = "Customer ID", right_index =  True)
sales = sales.merge(foods, how = "left", left_on = "Food ID", right_index = True)
sales.head()
# Out:
#    Customer ID  Food ID First Name Last Name  Gender    Company  \
# 0          537        9     Cheryl   Carroll  Female   Zoombeat
# 1           97        4     Amanda   Watkins  Female        Ozu
# 2          658        1    Patrick      Webb    Male  Browsebug
# 3          202        2      Louis  Campbell    Male  Rhynoodle
# 4          155        9    Carolyn      Diaz  Female   Gigazoom
#
#                       Occupation   Food Item  Price
# 0               Registered Nurse       Donut   0.99
# 1            Account Coordinator  Quesadilla   4.25
# 2  Community Outreach Specialist       Sushi   3.99
# 3     Account Representative III     Burrito   9.99
# 4     Database Administrator III       Donut   0.99

# %%
week1.merge(week2, how = "left", left_index = True, right_index = True, suffixes = [" - Week 1", " - Week 2"])
# Out:
#      Customer ID - Week 1  Food ID - Week 1  Customer ID - Week 2  \
# 0                     537                 9                   688
# 1                      97                 4                   813
# 2                     658                 1                   495
# 3                     202                 2                   189
# 4                     155                 9                   267
# 5                     213                 8                   310
# 6                     600                 1                   761
# 7                     503                 5                   443
# 8                      71                 3                   729
# 9                     174                 3                   741
# 10                    961                 9                   847
# 11                    966                 5                   156
# 12                    641                 4                   550
# ...

# %%
week1 = pd.read_csv("/home/gabrielajachs/Downloads/pandas/Restaurant - Week 1 Sales.csv")
pd.set_option('display.max_rows', 50000000)
week2 = pd.read_csv("/home/gabrielajachs/Downloads/pandas/Restaurant - Week 2 Sales.csv")
customers = pd.read_csv("/home/gabrielajachs/Downloads/pandas/Restaurant - Customers.csv")
foods = pd.read_csv("/home/gabrielajachs/Downloads/pandas/Restaurant - Foods.csv")
satisfaction = pd.read_csv("/home/gabrielajachs/Downloads/pandas/Restaurant - Week 1 Satisfaction.csv")

# %%
satisfaction
# Out:
#      Satisfaction Rating
# 0                      2
# 1                      7
# 2                      3
# 3                      7
# 4                     10
# 5                      3
# 6                      2
# 7                      5
# 8                     10
# 9                      7
# 10                     7
# 11                     5
# 12                     3
# 13                     2
# 14                     7
# 15                     4
# 16                     6
# 17                     1
# 18                     5
# 19                     5
# 20                     3
# 21                     2
# 22                     3
# 23                    10
# 24                     4
# 25                     9
# 26                     1
# 27                     4
# 28                     4
# 29                     9
# 30                     8
# 31                     9
# 32                     7
# 33                     1
# 34                     1
# 35                     3
# ...

# %%
week1.head()
# Out:
#    Customer ID  Food ID
# 0          537        9
# 1           97        4
# 2          658        1
# 3          202        2
# 4          155        9

# %%
week1.join(satisfaction).head()
# Out:
#    Customer ID  Food ID  Satisfaction Rating
# 0          537        9                    2
# 1           97        4                    7
# 2          658        1                    3
# 3          202        2                    7
# 4          155        9                   10
