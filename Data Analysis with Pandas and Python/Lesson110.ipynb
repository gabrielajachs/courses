# %%
import pandas as pd

# %%
bigmac = pd.read_csv("/home/gabrielajachs/Downloads/pandas/bigmac.csv")
#pd.set_option('display.max_rows', 50000000)
bigmac.head(3)
# Out:
#      Date    Country  Price in US Dollars
# 0  1/2016  Argentina                 2.39
# 1  1/2016  Australia                 3.74
# 2  1/2016     Brazil                 3.35

# %%
bigmac.dtypes
# Out:
# Date                    object
# Country                 object
# Price in US Dollars    float64
# dtype: object

# %%
bigmac.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 652 entries, 0 to 651
# Data columns (total 3 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 652 non-null    object
#  1   Country              652 non-null    object
#  2   Price in US Dollars  652 non-null    float64
# dtypes: float64(1), object(2)
# memory usage: 15.4+ KB

# %%
pd.set_option('display.max_rows', 50000000)

# %%
bigmac.set_index(keys = ["Date", "Country"])
# Out:
#                        Price in US Dollars
# Date   Country
# 1/2016 Argentina                      2.39
#        Australia                      3.74
#        Brazil                         3.35
#        Britain                        4.22
#        Canada                         4.14
#        Chile                          2.94
#        China                          2.68
#        Colombia                       2.43
#        Costa Rica                     4.02
#        Czech Republic                 2.98
#        Denmark                        4.32
#        Egypt                          2.16
#        Euro area                      4.00
#        Hong Kong                      2.48
#        Hungary                        3.08
#        India                          1.90
#        Indonesia                      2.19
#        Israel                         4.29
#        Japan                          3.12
#        Malaysia                       1.82
# ...

# %%
bigmac.set_index(keys = ["Country", "Date"])
# Out:
#                        Price in US Dollars
# Country        Date
# Argentina      1/2016                 2.39
# Australia      1/2016                 3.74
# Brazil         1/2016                 3.35
# Britain        1/2016                 4.22
# Canada         1/2016                 4.14
# Chile          1/2016                 2.94
# China          1/2016                 2.68
# Colombia       1/2016                 2.43
# Costa Rica     1/2016                 4.02
# Czech Republic 1/2016                 2.98
# Denmark        1/2016                 4.32
# Egypt          1/2016                 2.16
# Euro area      1/2016                 4.00
# Hong Kong      1/2016                 2.48
# Hungary        1/2016                 3.08
# India          1/2016                 1.90
# Indonesia      1/2016                 2.19
# Israel         1/2016                 4.29
# Japan          1/2016                 3.12
# Malaysia       1/2016                 1.82
# ...

# %%
bigmac.nunique()
# Out:
# Date                    12
# Country                 58
# Price in US Dollars    330
# dtype: int64

# %%
bigmac.set_index(keys = ["Date", "Country"], inplace = True)

# %%
bigmac.head(3)
# Out:
#                   Price in US Dollars
# Date   Country
# 1/2016 Argentina                 2.39
#        Australia                 3.74
#        Brazil                    3.35

# %%
bigmac.sort_index(inplace = True)
bigmac.head(3)
# Out:
#                   Price in US Dollars
# Date   Country
# 1/2010 Argentina                 1.84
#        Australia                 3.98
#        Brazil                    4.76

# %%
bigmac.index
# Out:
# MultiIndex([('1/2010',      'Argentina'),
#             ('1/2010',      'Australia'),
#             ('1/2010',         'Brazil'),
#             ('1/2010',        'Britain'),
#             ('1/2010',         'Canada'),
#             ('1/2010',          'Chile'),
#             ('1/2010',          'China'),
#             ('1/2010',       'Colombia'),
#             ('1/2010',     'Costa Rica'),
#             ('1/2010', 'Czech Republic'),
#             ...
#             ('7/2015',    'Switzerland'),
#             ('7/2015',         'Taiwan'),
#             ('7/2015',       'Thailand'),
#             ('7/2015',         'Turkey'),
#             ('7/2015',            'UAE'),
#             ('7/2015',        'Ukraine'),
#             ('7/2015',  'United States'),
#             ('7/2015',        'Uruguay'),
#             ('7/2015',      'Venezuela'),
#             ('7/2015',        'Vietnam')],
#            names=['Date', 'Country'], length=652)

# %%
bigmac.index.names
# Out:
# FrozenList(['Date', 'Country'])

# %%
type(bigmac.index)
# Out:
# pandas.core.indexes.multi.MultiIndex

# %%
bigmac.index[1]
# Out:
# ('1/2010', 'Australia')

# %%
bigmac.index[10]
# Out:
# ('1/2010', 'Denmark')

# %%
bigmac = pd.read_csv("/home/gabrielajachs/Downloads/pandas/bigmac.csv", parse_dates = ["Date"], index_col = ["Date", "Country"])
bigmac.sort_index(inplace = True)
pd.set_option('display.max_rows', 50000000)
bigmac.head(3)
# Out:
#                       Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                 1.84
#            Australia                 3.98
#            Brazil                    4.76

# %%
bigmac.index.get_level_values("Date")
# Out:
# DatetimeIndex(['2010-01-01', '2010-01-01', '2010-01-01', '2010-01-01',
#                '2010-01-01', '2010-01-01', '2010-01-01', '2010-01-01',
#                '2010-01-01', '2010-01-01',
#                ...
#                '2016-01-01', '2016-01-01', '2016-01-01', '2016-01-01',
#                '2016-01-01', '2016-01-01', '2016-01-01', '2016-01-01',
#                '2016-01-01', '2016-01-01'],
#               dtype='datetime64[ns]', name='Date', length=652, freq=None)

# %%
bigmac.index.get_level_values("Country")
bigmac.index.get_level_values(1)
# Out:
# Index(['Argentina', 'Australia', 'Brazil', 'Britain', 'Canada', 'Chile',
#        'China', 'Colombia', 'Costa Rica', 'Czech Republic',
#        ...
#        'Switzerland', 'Taiwan', 'Thailand', 'Turkey', 'UAE', 'Ukraine',
#        'United States', 'Uruguay', 'Venezuela', 'Vietnam'],
#       dtype='object', name='Country', length=652)

# %%
bigmac = pd.read_csv("/home/gabrielajachs/Downloads/pandas/bigmac.csv", parse_dates = ["Date"], index_col = ["Date", "Country"])
bigmac.sort_index(inplace = True)
pd.set_option('display.max_rows', 50000000)
bigmac.head(3)
# Out:
#                       Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                 1.84
#            Australia                 3.98
#            Brazil                    4.76

# %%
bigmac.index.set_names(names = ["Day", "Location"], inplace = True)

# %%
bigmac.head(3)
# Out:
#                       Price in US Dollars
# Day        Location
# 2010-01-01 Argentina                 1.84
#            Australia                 3.98
#            Brazil                    4.76

# %%
bigmac.index.set_names(names = "Date", level = 1)
# Out:
# MultiIndex([('2010-01-01',      'Argentina'),
#             ('2010-01-01',      'Australia'),
#             ('2010-01-01',         'Brazil'),
#             ('2010-01-01',        'Britain'),
#             ('2010-01-01',         'Canada'),
#             ('2010-01-01',          'Chile'),
#             ('2010-01-01',          'China'),
#             ('2010-01-01',       'Colombia'),
#             ('2010-01-01',     'Costa Rica'),
#             ('2010-01-01', 'Czech Republic'),
#             ...
#             ('2016-01-01',    'Switzerland'),
#             ('2016-01-01',         'Taiwan'),
#             ('2016-01-01',       'Thailand'),
#             ('2016-01-01',         'Turkey'),
#             ('2016-01-01',            'UAE'),
#             ('2016-01-01',        'Ukraine'),
#             ('2016-01-01',  'United States'),
#             ('2016-01-01',        'Uruguay'),
#             ('2016-01-01',      'Venezuela'),
#             ('2016-01-01',        'Vietnam')],
# ...

# %%
bigmac.index.set_names(names = "Date", level = "Day", inplace = True)

# %%
bigmac.head(3)
# Out:
#                       Price in US Dollars
# Date       Location
# 2010-01-01 Argentina                 1.84
#            Australia                 3.98
#            Brazil                    4.76

# %%
bigmac = pd.read_csv("/home/gabrielajachs/Downloads/pandas/bigmac.csv", parse_dates = ["Date"], index_col = ["Date", "Country"])
pd.set_option('display.max_rows', 50000000)
bigmac.head(3)
# Out:
#                       Price in US Dollars
# Date       Country
# 2016-01-01 Argentina                 2.39
#            Australia                 3.74
#            Brazil                    3.35

# %%
bigmac.sort_index()
# Out:
#                            Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                      1.84
#            Australia                      3.98
#            Brazil                         4.76
#            Britain                        3.67
#            Canada                         3.97
#            Chile                          3.18
#            China                          1.83
#            Colombia                       3.91
#            Costa Rica                     3.52
#            Czech Republic                 3.71
#            Denmark                        5.99
#            Egypt                          2.38
#            Euro area                      4.84
#            Hong Kong                      1.91
#            Hungary                        3.86
#            Indonesia                      2.24
#            Israel                         3.99
#            Japan                          3.50
# ...

# %%
bigmac.sort_index(ascending = True)
# Out:
#                            Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                      1.84
#            Australia                      3.98
#            Brazil                         4.76
#            Britain                        3.67
#            Canada                         3.97
#            Chile                          3.18
#            China                          1.83
#            Colombia                       3.91
#            Costa Rica                     3.52
#            Czech Republic                 3.71
#            Denmark                        5.99
#            Egypt                          2.38
#            Euro area                      4.84
#            Hong Kong                      1.91
#            Hungary                        3.86
#            Indonesia                      2.24
#            Israel                         3.99
#            Japan                          3.50
# ...

# %%
bigmac.sort_index(ascending = False)
# Out:
#                            Price in US Dollars
# Date       Country
# 2016-01-01 Vietnam                        2.67
#            Venezuela                      0.66
#            Uruguay                        3.74
#            United States                  4.93
#            Ukraine                        1.54
#            UAE                            3.54
#            Turkey                         3.41
#            Thailand                       3.09
#            Taiwan                         2.08
#            Switzerland                    6.44
#            Sweden                         5.23
#            Sri Lanka                      2.43
#            Spain                          3.76
#            South Korea                    3.59
#            South Africa                   1.77
#            Singapore                      3.27
#            Saudi Arabia                   3.20
#            Russia                         1.53
# ...

# %%
bigmac.sort_index(ascending = [True, False], inplace = True) #date will be ascending order and country will be descending order

# %%
bigmac.head(3)
# Out:
#                           Price in US Dollars
# Date       Country
# 2010-01-01 Uruguay                       3.32
#            United States                 3.58
#            Ukraine                       1.83

# %%
bigmac.sort_index(level = 0)
# Out:
#                            Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                      1.84
#            Australia                      3.98
#            Brazil                         4.76
#            Britain                        3.67
#            Canada                         3.97
#            Chile                          3.18
#            China                          1.83
#            Colombia                       3.91
#            Costa Rica                     3.52
#            Czech Republic                 3.71
#            Denmark                        5.99
#            Egypt                          2.38
#            Euro area                      4.84
#            Hong Kong                      1.91
#            Hungary                        3.86
#            Indonesia                      2.24
#            Israel                         3.99
#            Japan                          3.50
# ...

# %%
bigmac.sort_index(level = "Date")
# Out:
#                            Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                      1.84
#            Australia                      3.98
#            Brazil                         4.76
#            Britain                        3.67
#            Canada                         3.97
#            Chile                          3.18
#            China                          1.83
#            Colombia                       3.91
#            Costa Rica                     3.52
#            Czech Republic                 3.71
#            Denmark                        5.99
#            Egypt                          2.38
#            Euro area                      4.84
#            Hong Kong                      1.91
#            Hungary                        3.86
#            Indonesia                      2.24
#            Israel                         3.99
#            Japan                          3.50
# ...

# %%
bigmac.loc["2010-01-01", "Argentina"]
# Out:
# Price in US Dollars    1.84
# Name: (2010-01-01 00:00:00, Argentina), dtype: float64

# %%
bigmac.loc[("2010-01-01", "Argentina"), ["Price in US Dollars", "Price in US Dollars"]]
# Out:
#                       Price in US Dollars  Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                 1.84                 1.84

# %%
bigmac.head(3)
# Out:
#                           Price in US Dollars
# Date       Country
# 2010-01-01 Uruguay                       3.32
#            United States                 3.58
#            Ukraine                       1.83

# %%
bigmac.iloc[0]
# Out:
# Price in US Dollars    3.32
# Name: (2010-01-01 00:00:00, Uruguay), dtype: float64

# %%
bigmac = pd.read_csv("/home/gabrielajachs/Downloads/pandas/bigmac.csv", parse_dates = ["Date"], index_col = ["Date", "Country"])
bigmac.sort_index(inplace = True)
pd.set_option('display.max_rows', 50000000)
bigmac.head(3)
# Out:
#                       Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                 1.84
#            Australia                 3.98
#            Brazil                    4.76

# %%
bigmac = bigmac.transpose()
bigmac.head(3)
# Out:
# Date                2010-01-01                                              \
# Country              Argentina Australia Brazil Britain Canada Chile China
# Price in US Dollars       1.84      3.98   4.76    3.67   3.97  3.18  1.83
#
# Date                                                    ...  2016-01-01  \
# Country             Colombia Costa Rica Czech Republic  ... Switzerland
# Price in US Dollars     3.91       3.52           3.71  ...        6.44
#
# Date                                                                    \
# Country             Taiwan Thailand Turkey   UAE Ukraine United States
# Price in US Dollars   2.08     3.09   3.41  3.54    1.54          4.93
#
# Date
# Country             Uruguay Venezuela Vietnam
# Price in US Dollars    3.74      0.66    2.67
#
# [1 rows x 652 columns]

# %%
bigmac.loc[("Price in US Dollars",), ("2010-01-01", "Sri Lanka"):("2010-01-01", "Ukraine")]
# Out:
# Date                2010-01-01                                            \
# Country              Sri Lanka Sweden Switzerland Taiwan Thailand Turkey
# Price in US Dollars       1.83   5.51         6.3   2.36     2.11   3.83
#
# Date
# Country               UAE Ukraine
# Price in US Dollars  2.99    1.83

# %%
bigmac.head(3)
# Out:
# Date                2010-01-01                                              \
# Country              Argentina Australia Brazil Britain Canada Chile China
# Price in US Dollars       1.84      3.98   4.76    3.67   3.97  3.18  1.83
#
# Date                                                    ...  2016-01-01  \
# Country             Colombia Costa Rica Czech Republic  ... Switzerland
# Price in US Dollars     3.91       3.52           3.71  ...        6.44
#
# Date                                                                    \
# Country             Taiwan Thailand Turkey   UAE Ukraine United States
# Price in US Dollars   2.08     3.09   3.41  3.54    1.54          4.93
#
# Date
# Country             Uruguay Venezuela Vietnam
# Price in US Dollars    3.74      0.66    2.67
#
# [1 rows x 652 columns]

# %%
bigmac = pd.read_csv("/home/gabrielajachs/Downloads/pandas/bigmac.csv", parse_dates = ["Date"], index_col = ["Date", "Country"])
bigmac.sort_index(inplace = True)
pd.set_option('display.max_rows', 50000000)
bigmac.head(3)
# Out:
#                       Price in US Dollars
# Date       Country
# 2010-01-01 Argentina                 1.84
#            Australia                 3.98
#            Brazil                    4.76

# %%
bigmac.swaplevel("Date", "Country")
# Out:
#                            Price in US Dollars
# Country        Date
# Argentina      2010-01-01                 1.84
# Australia      2010-01-01                 3.98
# Brazil         2010-01-01                 4.76
# Britain        2010-01-01                 3.67
# Canada         2010-01-01                 3.97
# Chile          2010-01-01                 3.18
# China          2010-01-01                 1.83
# Colombia       2010-01-01                 3.91
# Costa Rica     2010-01-01                 3.52
# Czech Republic 2010-01-01                 3.71
# Denmark        2010-01-01                 5.99
# Egypt          2010-01-01                 2.38
# Euro area      2010-01-01                 4.84
# Hong Kong      2010-01-01                 1.91
# Hungary        2010-01-01                 3.86
# Indonesia      2010-01-01                 2.24
# Israel         2010-01-01                 3.99
# Japan          2010-01-01                 3.50
# ...

# %%
bigmac.swaplevel(1, 0)
# Out:
#                            Price in US Dollars
# Country        Date
# Argentina      2010-01-01                 1.84
# Australia      2010-01-01                 3.98
# Brazil         2010-01-01                 4.76
# Britain        2010-01-01                 3.67
# Canada         2010-01-01                 3.97
# Chile          2010-01-01                 3.18
# China          2010-01-01                 1.83
# Colombia       2010-01-01                 3.91
# Costa Rica     2010-01-01                 3.52
# Czech Republic 2010-01-01                 3.71
# Denmark        2010-01-01                 5.99
# Egypt          2010-01-01                 2.38
# Euro area      2010-01-01                 4.84
# Hong Kong      2010-01-01                 1.91
# Hungary        2010-01-01                 3.86
# Indonesia      2010-01-01                 2.24
# Israel         2010-01-01                 3.99
# Japan          2010-01-01                 3.50
# ...
