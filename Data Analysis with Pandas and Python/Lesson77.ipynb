# %%
import pandas as pd

# %%
bond = pd.read_csv("/home/gabrielajachs/Downloads/pandas/jamesbond.csv")
bond.head(3)
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2

# %%
bond.set_index(keys = "Film", inplace = True)

# %%
bond.head(3)
# Out:
#                        Year         Actor       Director  Box Office  Budget  \
# Film
# Dr. No                 1962  Sean Connery  Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery   Guy Hamilton       820.4    18.6
#
#                        Bond Actor Salary
# Film
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2

# %%
bond.reset_index()
bond.reset_index(drop = False)
bond.reset_index(drop = True)
bond.reset_index(drop = False, inplace = True)

# %%
bond.head(3)
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2

# %%
bond.set_index("Film", inplace = True)

# %%
bond.head(3)
# Out:
#                        Year         Actor       Director  Box Office  Budget  \
# Film
# Dr. No                 1962  Sean Connery  Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery   Guy Hamilton       820.4    18.6
#
#                        Bond Actor Salary
# Film
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2

# %%
bond.reset_index(inplace = True)
bond.set_index("Year", inplace = True)

# %%
bond.head(3)
# Out:
#                        Film         Actor       Director  Box Office  Budget  \
# Year
# 1962                 Dr. No  Sean Connery  Terence Young       448.8     7.0
# 1963  From Russia with Love  Sean Connery  Terence Young       543.8    12.6
# 1964             Goldfinger  Sean Connery   Guy Hamilton       820.4    18.6
#
#       Bond Actor Salary
# Year
# 1962                0.6
# 1963                1.6
# 1964                3.2

# %%
bond = pd.read_csv("/home/gabrielajachs/Downloads/pandas/jamesbond.csv", index_col = "Film")
bond.sort_index(inplace = True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
bond.loc["Goldfinger"]
bond.loc["GoldenEye"]
# Out:
# Year                            1995
# Actor                 Pierce Brosnan
# Director             Martin Campbell
# Box Office                     518.5
# Budget                          76.9
# Bond Actor Salary                5.1
# Name: GoldenEye, dtype: object

# %%
bond.loc["Casino Royale"]
# Out:
#                Year         Actor         Director  Box Office  Budget  \
# Film
# Casino Royale  2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale  1967   David Niven       Ken Hughes       315.0    85.0
#
#                Bond Actor Salary
# Film
# Casino Royale                3.3
# Casino Royale                NaN

# %%
bond.loc["Diamonds Are Forever":"From Russia with Love"] #from one movie to another
# Out:
#                        Year           Actor       Director  Box Office  \
# Film
# Diamonds Are Forever   1971    Sean Connery   Guy Hamilton       442.5
# Die Another Day        2002  Pierce Brosnan   Lee Tamahori       465.4
# Dr. No                 1962    Sean Connery  Terence Young       448.8
# For Your Eyes Only     1981     Roger Moore      John Glen       449.4
# From Russia with Love  1963    Sean Connery  Terence Young       543.8
#
#                        Budget  Bond Actor Salary
# Film
# Diamonds Are Forever     34.7                5.8
# Die Another Day         154.2               17.9
# Dr. No                    7.0                0.6
# For Your Eyes Only       60.2                NaN
# From Russia with Love    12.6                1.6

# %%
bond.loc["Diamonds Are Forever":"From Russia with Love":2] #with the 2, it will jump 2 rows
# Out:
#                        Year         Actor       Director  Box Office  Budget  \
# Film
# Diamonds Are Forever   1971  Sean Connery   Guy Hamilton       442.5    34.7
# Dr. No                 1962  Sean Connery  Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
#
#                        Bond Actor Salary
# Film
# Diamonds Are Forever                 5.8
# Dr. No                               0.6
# From Russia with Love                1.6

# %%
bond.loc["GoldenEye":]
bond[:"On Her Majesty's Secret Service"]
# Out:
#                                  Year           Actor         Director  \
# Film
# A View to a Kill                 1985     Roger Moore        John Glen
# Casino Royale                    2006    Daniel Craig  Martin Campbell
# Casino Royale                    1967     David Niven       Ken Hughes
# Diamonds Are Forever             1971    Sean Connery     Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan     Lee Tamahori
# Dr. No                           1962    Sean Connery    Terence Young
# For Your Eyes Only               1981     Roger Moore        John Glen
# From Russia with Love            1963    Sean Connery    Terence Young
# GoldenEye                        1995  Pierce Brosnan  Martin Campbell
# Goldfinger                       1964    Sean Connery     Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton        John Glen
# Live and Let Die                 1973     Roger Moore     Guy Hamilton
# ...

# %%
bond.loc[["Die Another Day", "Octopussy"]]
bond.loc[["Octopussy", "Die Another Day"]]
# Out:
#                  Year           Actor      Director  Box Office  Budget  \
# Film
# Octopussy        1983     Roger Moore     John Glen       373.8    53.9
# Die Another Day  2002  Pierce Brosnan  Lee Tamahori       465.4   154.2
#
#                  Bond Actor Salary
# Film
# Octopussy                      7.8
# Die Another Day               17.9

# %%
"Gold Bond" in bond.index #when I need to look if something exists in my database
# Out:
# False

# %%
bond = pd.read_csv("/home/gabrielajachs/Downloads/pandas/jamesbond.csv")
bond.head(3)
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2

# %%
bond.iloc[0]
# Out:
# Film                        Dr. No
# Year                          1962
# Actor                 Sean Connery
# Director             Terence Young
# Box Office                   448.8
# Budget                           7
# Bond Actor Salary              0.6
# Name: 0, dtype: object

# %%
bond.iloc[15]
# Out:
# Film                 A View to a Kill
# Year                             1985
# Actor                     Roger Moore
# Director                    John Glen
# Box Office                      275.2
# Budget                           54.5
# Bond Actor Salary                 9.1
# Name: 15, dtype: object

# %%
bond.iloc[[15,20]]
# Out:
#                        Film  Year           Actor       Director  Box Office  \
# 15         A View to a Kill  1985     Roger Moore      John Glen       275.2
# 20  The World Is Not Enough  1999  Pierce Brosnan  Michael Apted       439.5
#
#     Budget  Bond Actor Salary
# 15    54.5                9.1
# 20   158.3               13.5

# %%
bond.iloc[4:8]
# Out:
#                               Film  Year           Actor       Director  \
# 4                    Casino Royale  1967     David Niven     Ken Hughes
# 5              You Only Live Twice  1967    Sean Connery  Lewis Gilbert
# 6  On Her Majesty's Secret Service  1969  George Lazenby  Peter R. Hunt
# 7             Diamonds Are Forever  1971    Sean Connery   Guy Hamilton
#
#    Box Office  Budget  Bond Actor Salary
# 4       315.0    85.0                NaN
# 5       514.2    59.9                4.4
# 6       291.5    37.3                0.6
# 7       442.5    34.7                5.8

# %%
bond.iloc[20:]
# Out:
#                        Film  Year           Actor         Director  \
# 20  The World Is Not Enough  1999  Pierce Brosnan    Michael Apted
# 21          Die Another Day  2002  Pierce Brosnan     Lee Tamahori
# 22            Casino Royale  2006    Daniel Craig  Martin Campbell
# 23        Quantum of Solace  2008    Daniel Craig     Marc Forster
# 24                  Skyfall  2012    Daniel Craig       Sam Mendes
# 25                  Spectre  2015    Daniel Craig       Sam Mendes
#
#     Box Office  Budget  Bond Actor Salary
# 20       439.5   158.3               13.5
# 21       465.4   154.2               17.9
# 22       581.5   145.3                3.3
# 23       514.2   181.4                8.1
# 24       943.5   170.2               14.5
# 25       726.7   206.3                NaN

# %%
bond.iloc[:20]
# Out:
#                                Film  Year           Actor            Director  \
# 0                            Dr. No  1962    Sean Connery       Terence Young
# 1             From Russia with Love  1963    Sean Connery       Terence Young
# 2                        Goldfinger  1964    Sean Connery        Guy Hamilton
# 3                       Thunderball  1965    Sean Connery       Terence Young
# 4                     Casino Royale  1967     David Niven          Ken Hughes
# 5               You Only Live Twice  1967    Sean Connery       Lewis Gilbert
# 6   On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# 7              Diamonds Are Forever  1971    Sean Connery        Guy Hamilton
# 8                  Live and Let Die  1973     Roger Moore        Guy Hamilton
# 9       The Man with the Golden Gun  1974     Roger Moore        Guy Hamilton
# 10             The Spy Who Loved Me  1977     Roger Moore       Lewis Gilbert
# ...

# %%
bond = pd.read_csv("/home/gabrielajachs/Downloads/pandas/jamesbond.csv")
bond.head(3)
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2

# %%
bond.set_index("Film", inplace = True)
bond.sort_index(inplace = True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
bond.loc["GoldenEye"]
# Out:
# Year                            1995
# Actor                 Pierce Brosnan
# Director             Martin Campbell
# Box Office                     518.5
# Budget                          76.9
# Bond Actor Salary                5.1
# Name: GoldenEye, dtype: object

# %%
bond.iloc[0]
# Out:
# Year                        1985
# Actor                Roger Moore
# Director               John Glen
# Box Office                 275.2
# Budget                      54.5
# Bond Actor Salary            9.1
# Name: A View to a Kill, dtype: object

# %%
bond.iloc[[5, 6, 8]]
# Out:
#                     Year           Actor         Director  Box Office  Budget  \
# Film
# Dr. No              1962    Sean Connery    Terence Young       448.8     7.0
# For Your Eyes Only  1981     Roger Moore        John Glen       449.4    60.2
# GoldenEye           1995  Pierce Brosnan  Martin Campbell       518.5    76.9
#
#                     Bond Actor Salary
# Film
# Dr. No                            0.6
# For Your Eyes Only                NaN
# GoldenEye                         5.1

# %%
bond = pd.read_csv("/home/gabrielajachs/Downloads/pandas/jamesbond.csv", index_col = "Film")
bond.sort_index(inplace = True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
bond.loc["Moonraker", "Actor"] #I wanna see who is the actor in Moonraker
# Out:
# 'Roger Moore'

# %%
bond.loc["Moonraker", "Director"] #I wanna see who is the director in Moonraker
# Out:
# 'Lewis Gilbert'

# %%
bond.loc["Moonraker", ["Director", "Box Office"]]
bond.loc[["Moonraker", "A View to a Kill"] , ["Director", "Box Office"]] #to create a new table
# Out:
#                        Director  Box Office
# Film
# Moonraker         Lewis Gilbert       535.0
# A View to a Kill      John Glen       275.2

# %%
bond.loc["Moonraker", "Director":"Budget"]
# Out:
# Director      Lewis Gilbert
# Box Office              535
# Budget                 91.5
# Name: Moonraker, dtype: object

# %%
bond.loc["Moonraker":"Thunderball", "Director":"Budget"]
#moonraker is the film and it's first here, before the :
#so it will be at the Y
#then the thunderball is before the :, so it will be
#at the end of the Y
#then there is the coma ,
#which will indicate that the X begins
#and the X will have the columns between DIRECTOR to BUDGET
# Out:
#                                        Director  Box Office  Budget
# Film
# Moonraker                         Lewis Gilbert       535.0    91.5
# Never Say Never Again            Irvin Kershner       380.0    86.0
# Octopussy                             John Glen       373.8    53.9
# On Her Majesty's Secret Service   Peter R. Hunt       291.5    37.3
# Quantum of Solace                  Marc Forster       514.2   181.4
# Skyfall                              Sam Mendes       943.5   170.2
# Spectre                              Sam Mendes       726.7   206.3
# The Living Daylights                  John Glen       313.5    68.8
# The Man with the Golden Gun        Guy Hamilton       334.0    27.7
# The Spy Who Loved Me              Lewis Gilbert       533.0    45.1
# The World Is Not Enough           Michael Apted       439.5   158.3
# Thunderball                       Terence Young       848.1    41.9

# %%
bond.loc["Moonraker":, "Director":"Budget"]
# Out:
#                                            Director  Box Office  Budget
# Film
# Moonraker                             Lewis Gilbert       535.0    91.5
# Never Say Never Again                Irvin Kershner       380.0    86.0
# Octopussy                                 John Glen       373.8    53.9
# On Her Majesty's Secret Service       Peter R. Hunt       291.5    37.3
# Quantum of Solace                      Marc Forster       514.2   181.4
# Skyfall                                  Sam Mendes       943.5   170.2
# Spectre                                  Sam Mendes       726.7   206.3
# The Living Daylights                      John Glen       313.5    68.8
# The Man with the Golden Gun            Guy Hamilton       334.0    27.7
# The Spy Who Loved Me                  Lewis Gilbert       533.0    45.1
# The World Is Not Enough               Michael Apted       439.5   158.3
# Thunderball                           Terence Young       848.1    41.9
# ...

# %%
bond.iloc[14, 2:5]
# Out:
# Director      John Glen
# Box Office        373.8
# Budget             53.9
# Name: Octopussy, dtype: object

# %%
bond.iloc[[14, 17], 2:5]
# Out:
#              Director  Box Office  Budget
# Film
# Octopussy   John Glen       373.8    53.9
# Skyfall    Sam Mendes       943.5   170.2

# %%
bond.iloc[14, 2]
# Out:
# 'John Glen'

# %%
bond.iloc[:7, :3]
# Out:
#                       Year           Actor         Director
# Film
# A View to a Kill      1985     Roger Moore        John Glen
# Casino Royale         2006    Daniel Craig  Martin Campbell
# Casino Royale         1967     David Niven       Ken Hughes
# Diamonds Are Forever  1971    Sean Connery     Guy Hamilton
# Die Another Day       2002  Pierce Brosnan     Lee Tamahori
# Dr. No                1962    Sean Connery    Terence Young
# For Your Eyes Only    1981     Roger Moore        John Glen

# %%
bond = pd.read_csv("/home/gabrielajachs/Downloads/pandas/jamesbond.csv", index_col = "Film")
bond.sort_index(inplace = True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
bond.loc["Dr. No", "Actor"] = "Sir Sean Connery"

# %%
bond.loc["Dr. No", "Actor"]
# Out:
# 'Sir Sean Connery'

# %%
bond = pd.read_csv("/home/gabrielajachs/Downloads/pandas/jamesbond.csv", index_col = "Film")
bond.sort_index(inplace = True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
actor_is_sean_connery = bond["Actor"] == "Sean Connery"

# %%
bond[actor_is_sean_connery]
# Out:
#                        Year         Actor        Director  Box Office  Budget  \
# Film
# Diamonds Are Forever   1971  Sean Connery    Guy Hamilton       442.5    34.7
# Dr. No                 1962  Sean Connery   Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery   Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery    Guy Hamilton       820.4    18.6
# Never Say Never Again  1983  Sean Connery  Irvin Kershner       380.0    86.0
# Thunderball            1965  Sean Connery   Terence Young       848.1    41.9
# You Only Live Twice    1967  Sean Connery   Lewis Gilbert       514.2    59.9
#
#                        Bond Actor Salary
# Film
# Diamonds Are Forever                 5.8
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Never Say Never Again                NaN
# Thunderball                          4.7
# ...

# %%
bond.loc[actor_is_sean_connery]
# Out:
#                        Year         Actor        Director  Box Office  Budget  \
# Film
# Diamonds Are Forever   1971  Sean Connery    Guy Hamilton       442.5    34.7
# Dr. No                 1962  Sean Connery   Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery   Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery    Guy Hamilton       820.4    18.6
# Never Say Never Again  1983  Sean Connery  Irvin Kershner       380.0    86.0
# Thunderball            1965  Sean Connery   Terence Young       848.1    41.9
# You Only Live Twice    1967  Sean Connery   Lewis Gilbert       514.2    59.9
#
#                        Bond Actor Salary
# Film
# Diamonds Are Forever                 5.8
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Never Say Never Again                NaN
# Thunderball                          4.7
# ...

# %%
bond = pd.read_csv("/home/gabrielajachs/Downloads/pandas/jamesbond.csv", index_col = "Film")
bond.sort_index(inplace = True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
bond.rename(mapper = {"Golden Eye": "Golden Eye", 
                      "The World Is Not Enough": "Best Bond Movie Ever"})

bond.rename(mapper = {"Golden Eye": "Golden Eye", 
                      "The World Is Not Enough": "Best Bond Movie Ever"}, axis = 0)

bond.rename(mapper = {"Golden Eye": "Golden Eye", 
                      "The World Is Not Enough": "Best Bond Movie Ever"}, axis = "rows")

bond.rename(mapper = {"Golden Eye": "Golden Eye", 
                      "The World Is Not Enough": "Best Bond Movie Ever"}, axis = "index")

bond.rename(index = {"Golden Eye": "Golden Eye", 
                      "The World Is Not Enough": "Best Bond Movie Ever"}, inplace = True)
bond
# Out:
#                                  Year           Actor            Director  \
# Film
# A View to a Kill                 1985     Roger Moore           John Glen
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Dr. No                           1962    Sean Connery       Terence Young
# For Your Eyes Only               1981     Roger Moore           John Glen
# From Russia with Love            1963    Sean Connery       Terence Young
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# ...

# %%
bond.head(1)
# Out:
#                   Year        Actor   Director  Box Office  Budget  \
# Film
# A View to a Kill  1985  Roger Moore  John Glen       275.2    54.5
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1

# %%
bond.rename(mapper = {"Year":"Release Date", "Box Office":"Renevue"}, axis = 1)
#this will change the name of the columns
# Out:
#                                  Release Date           Actor  \
# Film
# A View to a Kill                         1985     Roger Moore
# Casino Royale                            2006    Daniel Craig
# Casino Royale                            1967     David Niven
# Diamonds Are Forever                     1971    Sean Connery
# Die Another Day                          2002  Pierce Brosnan
# Dr. No                                   1962    Sean Connery
# For Your Eyes Only                       1981     Roger Moore
# From Russia with Love                    1963    Sean Connery
# GoldenEye                                1995  Pierce Brosnan
# Goldfinger                               1964    Sean Connery
# Licence to Kill                          1989  Timothy Dalton
# Live and Let Die                         1973     Roger Moore
# Moonraker                                1979     Roger Moore
# Never Say Never Again                    1983    Sean Connery
# ...

# %%
bond.rename(mapper = {"Year":"Release Date", "Box Office":"Renevue"}, axis = "columns")
# Out:
#                                  Release Date           Actor  \
# Film
# A View to a Kill                         1985     Roger Moore
# Casino Royale                            2006    Daniel Craig
# Casino Royale                            1967     David Niven
# Diamonds Are Forever                     1971    Sean Connery
# Die Another Day                          2002  Pierce Brosnan
# Dr. No                                   1962    Sean Connery
# For Your Eyes Only                       1981     Roger Moore
# From Russia with Love                    1963    Sean Connery
# GoldenEye                                1995  Pierce Brosnan
# Goldfinger                               1964    Sean Connery
# Licence to Kill                          1989  Timothy Dalton
# Live and Let Die                         1973     Roger Moore
# Moonraker                                1979     Roger Moore
# Never Say Never Again                    1983    Sean Connery
# ...

# %%
bond.rename(columns = {"Year":"Release Date", "Box Office":"Renevue"})
bond.rename(columns = {"Year":"Release Date", "Box Office":"Renevue"}, inplace = True)

# %%
bond.head(1)
# Out:
#                   Release Date        Actor   Director  Renevue  Budget  \
# Film
# A View to a Kill          1985  Roger Moore  John Glen    275.2    54.5
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1

# %%
bond.columns = ["Year of Release", "Actor", "Director", "Gross", "Cost", "Salary"]

# %%
bond.head(1)
# Out:
#                   Year of Release        Actor   Director  Gross  Cost  Salary
# Film
# A View to a Kill             1985  Roger Moore  John Glen  275.2  54.5     9.1

# %%
bond = pd.read_csv("/home/gabrielajachs/Downloads/pandas/jamesbond.csv", index_col = "Film")
bond.sort_index(inplace = True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
bond.drop(["A View to a Kill", "Die Another Day", "From Russia with Love"])
# Out:
#                                  Year           Actor            Director  \
# Film
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Dr. No                           1962    Sean Connery       Terence Young
# For Your Eyes Only               1981     Roger Moore           John Glen
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# Moonraker                        1979     Roger Moore       Lewis Gilbert
# Never Say Never Again            1983    Sean Connery      Irvin Kershner
# Octopussy                        1983     Roger Moore           John Glen
# ...

# %%
bond.drop("Casino Royale")
# Out:
#                                  Year           Actor            Director  \
# Film
# A View to a Kill                 1985     Roger Moore           John Glen
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Dr. No                           1962    Sean Connery       Terence Young
# For Your Eyes Only               1981     Roger Moore           John Glen
# From Russia with Love            1963    Sean Connery       Terence Young
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# Moonraker                        1979     Roger Moore       Lewis Gilbert
# Never Say Never Again            1983    Sean Connery      Irvin Kershner
# ...

# %%
bond.drop("Box Office", axis = "columns")
# Out:
#                                  Year           Actor            Director  \
# Film
# A View to a Kill                 1985     Roger Moore           John Glen
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Dr. No                           1962    Sean Connery       Terence Young
# For Your Eyes Only               1981     Roger Moore           John Glen
# From Russia with Love            1963    Sean Connery       Terence Young
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Live and Let Die                 1973     Roger Moore        Guy Hamilton
# ...

# %%
bond.drop(labels = ["Box Office", "Bond Actor Salary", "Actor"], axis = "columns", inplace = True)

# %%
bond = pd.read_csv("/home/gabrielajachs/Downloads/pandas/jamesbond.csv", index_col = "Film")
bond.sort_index(inplace = True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
actor = bond.pop("Actor")

# %%
actor
# Out:
# Film
# A View to a Kill                      Roger Moore
# Casino Royale                        Daniel Craig
# Casino Royale                         David Niven
# Diamonds Are Forever                 Sean Connery
# Die Another Day                    Pierce Brosnan
# Dr. No                               Sean Connery
# For Your Eyes Only                    Roger Moore
# From Russia with Love                Sean Connery
# GoldenEye                          Pierce Brosnan
# Goldfinger                           Sean Connery
# Licence to Kill                    Timothy Dalton
# Live and Let Die                      Roger Moore
# Moonraker                             Roger Moore
# Never Say Never Again                Sean Connery
# Octopussy                             Roger Moore
# On Her Majesty's Secret Service    George Lazenby
# Quantum of Solace                    Daniel Craig
# Skyfall                              Daniel Craig
# Spectre                              Daniel Craig
# ...

# %%
bond
# Out:
#                                  Year            Director  Box Office  Budget  \
# Film
# A View to a Kill                 1985           John Glen       275.2    54.5
# Casino Royale                    2006     Martin Campbell       581.5   145.3
# Casino Royale                    1967          Ken Hughes       315.0    85.0
# Diamonds Are Forever             1971        Guy Hamilton       442.5    34.7
# Die Another Day                  2002        Lee Tamahori       465.4   154.2
# Dr. No                           1962       Terence Young       448.8     7.0
# For Your Eyes Only               1981           John Glen       449.4    60.2
# From Russia with Love            1963       Terence Young       543.8    12.6
# GoldenEye                        1995     Martin Campbell       518.5    76.9
# Goldfinger                       1964        Guy Hamilton       820.4    18.6
# Licence to Kill                  1989           John Glen       250.9    56.7
# ...

# %%
#del bond["Director"] #to delete a column

# %%
bond
# Out:
#                                  Year            Director  Box Office  Budget  \
# Film
# A View to a Kill                 1985           John Glen       275.2    54.5
# Casino Royale                    2006     Martin Campbell       581.5   145.3
# Casino Royale                    1967          Ken Hughes       315.0    85.0
# Diamonds Are Forever             1971        Guy Hamilton       442.5    34.7
# Die Another Day                  2002        Lee Tamahori       465.4   154.2
# Dr. No                           1962       Terence Young       448.8     7.0
# For Your Eyes Only               1981           John Glen       449.4    60.2
# From Russia with Love            1963       Terence Young       543.8    12.6
# GoldenEye                        1995     Martin Campbell       518.5    76.9
# Goldfinger                       1964        Guy Hamilton       820.4    18.6
# Licence to Kill                  1989           John Glen       250.9    56.7
# ...

# %%
bond = pd.read_csv("/home/gabrielajachs/Downloads/pandas/jamesbond.csv", index_col = "Film")
bond.sort_index(inplace = True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
bond.sample(n = 5)
# Out:
#                              Year           Actor       Director  Box Office  \
# Film
# Octopussy                    1983     Roger Moore      John Glen       373.8
# A View to a Kill             1985     Roger Moore      John Glen       275.2
# Thunderball                  1965    Sean Connery  Terence Young       848.1
# The Man with the Golden Gun  1974     Roger Moore   Guy Hamilton       334.0
# Die Another Day              2002  Pierce Brosnan   Lee Tamahori       465.4
#
#                              Budget  Bond Actor Salary
# Film
# Octopussy                      53.9                7.8
# A View to a Kill               54.5                9.1
# Thunderball                    41.9                4.7
# The Man with the Golden Gun    27.7                NaN
# Die Another Day               154.2               17.9

# %%
bond.sample(frac = .25)
# Out:
#                        Year         Actor        Director  Box Office  Budget  \
# Film
# For Your Eyes Only     1981   Roger Moore       John Glen       449.4    60.2
# Diamonds Are Forever   1971  Sean Connery    Guy Hamilton       442.5    34.7
# You Only Live Twice    1967  Sean Connery   Lewis Gilbert       514.2    59.9
# Thunderball            1965  Sean Connery   Terence Young       848.1    41.9
# Never Say Never Again  1983  Sean Connery  Irvin Kershner       380.0    86.0
# Skyfall                2012  Daniel Craig      Sam Mendes       943.5   170.2
#
#                        Bond Actor Salary
# Film
# For Your Eyes Only                   NaN
# Diamonds Are Forever                 5.8
# You Only Live Twice                  4.4
# Thunderball                          4.7
# Never Say Never Again                NaN
# Skyfall                             14.5

# %%
bond.sample(n = 3, axis = "rows")
# Out:
#                      Year           Actor            Director  Box Office  \
# Film
# Tomorrow Never Dies  1997  Pierce Brosnan  Roger Spottiswoode       463.2
# You Only Live Twice  1967    Sean Connery       Lewis Gilbert       514.2
# Live and Let Die     1973     Roger Moore        Guy Hamilton       460.3
#
#                      Budget  Bond Actor Salary
# Film
# Tomorrow Never Dies   133.9               10.0
# You Only Live Twice    59.9                4.4
# Live and Let Die       30.8                NaN

# %%
bond.sample(n = 3, axis = 1)
# Out:
#                                  Budget            Director  Bond Actor Salary
# Film
# A View to a Kill                   54.5           John Glen                9.1
# Casino Royale                     145.3     Martin Campbell                3.3
# Casino Royale                      85.0          Ken Hughes                NaN
# Diamonds Are Forever               34.7        Guy Hamilton                5.8
# Die Another Day                   154.2        Lee Tamahori               17.9
# Dr. No                              7.0       Terence Young                0.6
# For Your Eyes Only                 60.2           John Glen                NaN
# From Russia with Love              12.6       Terence Young                1.6
# GoldenEye                          76.9     Martin Campbell                5.1
# Goldfinger                         18.6        Guy Hamilton                3.2
# Licence to Kill                    56.7           John Glen                7.9
# ...

# %%
bond.sort_values("Box Office", ascending = False).head(3)
# Out:
#              Year         Actor       Director  Box Office  Budget  \
# Film
# Skyfall      2012  Daniel Craig     Sam Mendes       943.5   170.2
# Thunderball  1965  Sean Connery  Terence Young       848.1    41.9
# Goldfinger   1964  Sean Connery   Guy Hamilton       820.4    18.6
#
#              Bond Actor Salary
# Film
# Skyfall                   14.5
# Thunderball                4.7
# Goldfinger                 3.2

# %%
bond.nlargest(3, columns = "Box Office")
# Out:
#              Year         Actor       Director  Box Office  Budget  \
# Film
# Skyfall      2012  Daniel Craig     Sam Mendes       943.5   170.2
# Thunderball  1965  Sean Connery  Terence Young       848.1    41.9
# Goldfinger   1964  Sean Connery   Guy Hamilton       820.4    18.6
#
#              Bond Actor Salary
# Film
# Skyfall                   14.5
# Thunderball                4.7
# Goldfinger                 3.2

# %%
bond.nsmallest(n = 2, columns = "Box Office")
# Out:
#                   Year           Actor   Director  Box Office  Budget  \
# Film
# Licence to Kill   1989  Timothy Dalton  John Glen       250.9    56.7
# A View to a Kill  1985     Roger Moore  John Glen       275.2    54.5
#
#                   Bond Actor Salary
# Film
# Licence to Kill                 7.9
# A View to a Kill                9.1

# %%
bond.nlargest(3, columns = "Budget")
# Out:
#                    Year         Actor      Director  Box Office  Budget  \
# Film
# Spectre            2015  Daniel Craig    Sam Mendes       726.7   206.3
# Quantum of Solace  2008  Daniel Craig  Marc Forster       514.2   181.4
# Skyfall            2012  Daniel Craig    Sam Mendes       943.5   170.2
#
#                    Bond Actor Salary
# Film
# Spectre                          NaN
# Quantum of Solace                8.1
# Skyfall                         14.5

# %%
bond.nsmallest(n = 6, columns = "Bond Actor Salary")
# Out:
#                                  Year           Actor         Director  \
# Film
# Dr. No                           1962    Sean Connery    Terence Young
# On Her Majesty's Secret Service  1969  George Lazenby    Peter R. Hunt
# From Russia with Love            1963    Sean Connery    Terence Young
# Goldfinger                       1964    Sean Connery     Guy Hamilton
# Casino Royale                    2006    Daniel Craig  Martin Campbell
# You Only Live Twice              1967    Sean Connery    Lewis Gilbert
#
#                                  Box Office  Budget  Bond Actor Salary
# Film
# Dr. No                                448.8     7.0                0.6
# On Her Majesty's Secret Service       291.5    37.3                0.6
# From Russia with Love                 543.8    12.6                1.6
# Goldfinger                            820.4    18.6                3.2
# Casino Royale                         581.5   145.3                3.3
# ...

# %%
bond["Box Office"].nlargest(8)
# Out:
# Film
# Skyfall                  943.5
# Thunderball              848.1
# Goldfinger               820.4
# Spectre                  726.7
# Casino Royale            581.5
# From Russia with Love    543.8
# Moonraker                535.0
# The Spy Who Loved Me     533.0
# Name: Box Office, dtype: float64

# %%
bond["Year"].nsmallest(2)
# Out:
# Film
# Dr. No                   1962
# From Russia with Love    1963
# Name: Year, dtype: int64

# %%
bond = pd.read_csv("/home/gabrielajachs/Downloads/pandas/jamesbond.csv", index_col = "Film")
bond.sort_index(inplace = True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
bond["Actor"] == "Sean Connery" #only where there is True is because it's Sean Connery
# Out:
# Film
# A View to a Kill                   False
# Casino Royale                      False
# Casino Royale                      False
# Diamonds Are Forever                True
# Die Another Day                    False
# Dr. No                              True
# For Your Eyes Only                 False
# From Russia with Love               True
# GoldenEye                          False
# Goldfinger                          True
# Licence to Kill                    False
# Live and Let Die                   False
# Moonraker                          False
# Never Say Never Again               True
# Octopussy                          False
# On Her Majesty's Secret Service    False
# Quantum of Solace                  False
# Skyfall                            False
# Spectre                            False
# The Living Daylights               False
# The Man with the Golden Gun        False
# The Spy Who Loved Me               False
# The World Is Not Enough            False
# ...

# %%
mask = bond["Actor"] == "Sean Connery"
bond[mask] #will only show the rows where there is Sean Connery
# Out:
#                        Year         Actor        Director  Box Office  Budget  \
# Film
# Diamonds Are Forever   1971  Sean Connery    Guy Hamilton       442.5    34.7
# Dr. No                 1962  Sean Connery   Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery   Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery    Guy Hamilton       820.4    18.6
# Never Say Never Again  1983  Sean Connery  Irvin Kershner       380.0    86.0
# Thunderball            1965  Sean Connery   Terence Young       848.1    41.9
# You Only Live Twice    1967  Sean Connery   Lewis Gilbert       514.2    59.9
#
#                        Bond Actor Salary
# Film
# Diamonds Are Forever                 5.8
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Never Say Never Again                NaN
# Thunderball                          4.7
# ...

# %%
bond.where(mask) #where there isn't Sean Connery, it wil show NAN
# Out:
#                                    Year         Actor        Director  \
# Film
# A View to a Kill                    NaN           NaN             NaN
# Casino Royale                       NaN           NaN             NaN
# Casino Royale                       NaN           NaN             NaN
# Diamonds Are Forever             1971.0  Sean Connery    Guy Hamilton
# Die Another Day                     NaN           NaN             NaN
# Dr. No                           1962.0  Sean Connery   Terence Young
# For Your Eyes Only                  NaN           NaN             NaN
# From Russia with Love            1963.0  Sean Connery   Terence Young
# GoldenEye                           NaN           NaN             NaN
# Goldfinger                       1964.0  Sean Connery    Guy Hamilton
# Licence to Kill                     NaN           NaN             NaN
# Live and Let Die                    NaN           NaN             NaN
# ...

# %%
bond.where(bond["Box Office"] > 800)
# Out:
#                                    Year         Actor       Director  \
# Film
# A View to a Kill                    NaN           NaN            NaN
# Casino Royale                       NaN           NaN            NaN
# Casino Royale                       NaN           NaN            NaN
# Diamonds Are Forever                NaN           NaN            NaN
# Die Another Day                     NaN           NaN            NaN
# Dr. No                              NaN           NaN            NaN
# For Your Eyes Only                  NaN           NaN            NaN
# From Russia with Love               NaN           NaN            NaN
# GoldenEye                           NaN           NaN            NaN
# Goldfinger                       1964.0  Sean Connery   Guy Hamilton
# Licence to Kill                     NaN           NaN            NaN
# Live and Let Die                    NaN           NaN            NaN
# ...

# %%
mask2 = bond["Box Office"] > 800

# %%
bond.where(mask & mask2)
# Out:
#                                    Year         Actor       Director  \
# Film
# A View to a Kill                    NaN           NaN            NaN
# Casino Royale                       NaN           NaN            NaN
# Casino Royale                       NaN           NaN            NaN
# Diamonds Are Forever                NaN           NaN            NaN
# Die Another Day                     NaN           NaN            NaN
# Dr. No                              NaN           NaN            NaN
# For Your Eyes Only                  NaN           NaN            NaN
# From Russia with Love               NaN           NaN            NaN
# GoldenEye                           NaN           NaN            NaN
# Goldfinger                       1964.0  Sean Connery   Guy Hamilton
# Licence to Kill                     NaN           NaN            NaN
# Live and Let Die                    NaN           NaN            NaN
# ...

# %%
bond = pd.read_csv("/home/gabrielajachs/Downloads/pandas/jamesbond.csv", index_col = "Film")
bond.sort_index(inplace = True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
bond.columns
# Out:
# Index(['Year', 'Actor', 'Director', 'Box Office', 'Budget',
#        'Bond Actor Salary'],
#       dtype='object')

# %%
bond.columns = [column_name.replace(" ", "_") for column_name in bond.columns]
bond.head(1)
# Out:
#                   Year        Actor   Director  Box_Office  Budget  \
# Film
# A View to a Kill  1985  Roger Moore  John Glen       275.2    54.5
#
#                   Bond_Actor_Salary
# Film
# A View to a Kill                9.1

# %%
bond.query('Actor == "Sean Connery"')
# Out:
#                        Year         Actor        Director  Box_Office  Budget  \
# Film
# Diamonds Are Forever   1971  Sean Connery    Guy Hamilton       442.5    34.7
# Dr. No                 1962  Sean Connery   Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery   Terence Young       543.8    12.6
# Goldfinger             1964  Sean Connery    Guy Hamilton       820.4    18.6
# Never Say Never Again  1983  Sean Connery  Irvin Kershner       380.0    86.0
# Thunderball            1965  Sean Connery   Terence Young       848.1    41.9
# You Only Live Twice    1967  Sean Connery   Lewis Gilbert       514.2    59.9
#
#                        Bond_Actor_Salary
# Film
# Diamonds Are Forever                 5.8
# Dr. No                               0.6
# From Russia with Love                1.6
# Goldfinger                           3.2
# Never Say Never Again                NaN
# Thunderball                          4.7
# ...

# %%
bond.query('Director == "Terence Young"')
# Out:
#                        Year         Actor       Director  Box_Office  Budget  \
# Film
# Dr. No                 1962  Sean Connery  Terence Young       448.8     7.0
# From Russia with Love  1963  Sean Connery  Terence Young       543.8    12.6
# Thunderball            1965  Sean Connery  Terence Young       848.1    41.9
#
#                        Bond_Actor_Salary
# Film
# Dr. No                               0.6
# From Russia with Love                1.6
# Thunderball                          4.7

# %%
bond.query('Actor != "Roger Moore"')
# Out:
#                                  Year           Actor            Director  \
# Film
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Diamonds Are Forever             1971    Sean Connery        Guy Hamilton
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# Dr. No                           1962    Sean Connery       Terence Young
# From Russia with Love            1963    Sean Connery       Terence Young
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Goldfinger                       1964    Sean Connery        Guy Hamilton
# Licence to Kill                  1989  Timothy Dalton           John Glen
# Never Say Never Again            1983    Sean Connery      Irvin Kershner
# On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# Quantum of Solace                2008    Daniel Craig        Marc Forster
# ...

# %%
bond.query("Box_Office > 600")
# Out:
#              Year         Actor       Director  Box_Office  Budget  \
# Film
# Goldfinger   1964  Sean Connery   Guy Hamilton       820.4    18.6
# Skyfall      2012  Daniel Craig     Sam Mendes       943.5   170.2
# Spectre      2015  Daniel Craig     Sam Mendes       726.7   206.3
# Thunderball  1965  Sean Connery  Terence Young       848.1    41.9
#
#              Bond_Actor_Salary
# Film
# Goldfinger                 3.2
# Skyfall                   14.5
# Spectre                    NaN
# Thunderball                4.7

# %%
bond.query("Actor == 'Roger Moore'")
# Out:
#                              Year        Actor       Director  Box_Office  \
# Film
# A View to a Kill             1985  Roger Moore      John Glen       275.2
# For Your Eyes Only           1981  Roger Moore      John Glen       449.4
# Live and Let Die             1973  Roger Moore   Guy Hamilton       460.3
# Moonraker                    1979  Roger Moore  Lewis Gilbert       535.0
# Octopussy                    1983  Roger Moore      John Glen       373.8
# The Man with the Golden Gun  1974  Roger Moore   Guy Hamilton       334.0
# The Spy Who Loved Me         1977  Roger Moore  Lewis Gilbert       533.0
#
#                              Budget  Bond_Actor_Salary
# Film
# A View to a Kill               54.5                9.1
# For Your Eyes Only             60.2                NaN
# Live and Let Die               30.8                NaN
# Moonraker                      91.5                NaN
# Octopussy                      53.9                7.8
# ...

# %%
bond.query("Actor == 'Roger moore' or Director == 'John Glen'")
# Out:
#                       Year           Actor   Director  Box_Office  Budget  \
# Film
# A View to a Kill      1985     Roger Moore  John Glen       275.2    54.5
# For Your Eyes Only    1981     Roger Moore  John Glen       449.4    60.2
# Licence to Kill       1989  Timothy Dalton  John Glen       250.9    56.7
# Octopussy             1983     Roger Moore  John Glen       373.8    53.9
# The Living Daylights  1987  Timothy Dalton  John Glen       313.5    68.8
#
#                       Bond_Actor_Salary
# Film
# A View to a Kill                    9.1
# For Your Eyes Only                  NaN
# Licence to Kill                     7.9
# Octopussy                           7.8
# The Living Daylights                5.2

# %%
bond.query("Actor in ['Timothy Dalton', 'George Lazenby']")
# Out:
#                                  Year           Actor       Director  \
# Film
# Licence to Kill                  1989  Timothy Dalton      John Glen
# On Her Majesty's Secret Service  1969  George Lazenby  Peter R. Hunt
# The Living Daylights             1987  Timothy Dalton      John Glen
#
#                                  Box_Office  Budget  Bond_Actor_Salary
# Film
# Licence to Kill                       250.9    56.7                7.9
# On Her Majesty's Secret Service       291.5    37.3                0.6
# The Living Daylights                  313.5    68.8                5.2

# %%
bond.query("Actor not in ['Sean Connery', 'Roger Moore']")
# Out:
#                                  Year           Actor            Director  \
# Film
# Casino Royale                    2006    Daniel Craig     Martin Campbell
# Casino Royale                    1967     David Niven          Ken Hughes
# Die Another Day                  2002  Pierce Brosnan        Lee Tamahori
# GoldenEye                        1995  Pierce Brosnan     Martin Campbell
# Licence to Kill                  1989  Timothy Dalton           John Glen
# On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# Quantum of Solace                2008    Daniel Craig        Marc Forster
# Skyfall                          2012    Daniel Craig          Sam Mendes
# Spectre                          2015    Daniel Craig          Sam Mendes
# The Living Daylights             1987  Timothy Dalton           John Glen
# The World Is Not Enough          1999  Pierce Brosnan       Michael Apted
# Tomorrow Never Dies              1997  Pierce Brosnan  Roger Spottiswoode
#
# ...

# %%
bond = pd.read_csv("/home/gabrielajachs/Downloads/pandas/jamesbond.csv", index_col = "Film")
bond.sort_index(inplace = True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
def convert_to_string_and_add_millions(number):
    return str(number) + "MILLIONS!"

bond["Box Office"] = bond["Box Office"].apply(convert_to_string_and_add_millions)

# %%
bond["Budget"].apply(convert_to_string_and_add_millions)
# Out:
# Film
# A View to a Kill                    54.5MILLIONS!
# Casino Royale                      145.3MILLIONS!
# Casino Royale                       85.0MILLIONS!
# Diamonds Are Forever                34.7MILLIONS!
# Die Another Day                    154.2MILLIONS!
# Dr. No                               7.0MILLIONS!
# For Your Eyes Only                  60.2MILLIONS!
# From Russia with Love               12.6MILLIONS!
# GoldenEye                           76.9MILLIONS!
# Goldfinger                          18.6MILLIONS!
# Licence to Kill                     56.7MILLIONS!
# Live and Let Die                    30.8MILLIONS!
# Moonraker                           91.5MILLIONS!
# Never Say Never Again               86.0MILLIONS!
# Octopussy                           53.9MILLIONS!
# On Her Majesty's Secret Service     37.3MILLIONS!
# Quantum of Solace                  181.4MILLIONS!
# Skyfall                            170.2MILLIONS!
# Spectre                            206.3MILLIONS!
# ...

# %%
def convert_to_string_and_add_millions(number):
    return str(number) + "MILLIONS!"

# %%
columns = ["Box Office", "Budget", "Bond Actor Salary"]
for col in columns:
    bond[col] = bond[col].apply(convert_to_string_and_add_millions)

# %%
bond.head(3)
# Out:
#                   Year         Actor         Director  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen
# Casino Royale     2006  Daniel Craig  Martin Campbell
# Casino Royale     1967   David Niven       Ken Hughes
#
#                                Box Office          Budget Bond Actor Salary
# Film
# A View to a Kill  275.2MILLIONS!MILLIONS!   54.5MILLIONS!      9.1MILLIONS!
# Casino Royale     581.5MILLIONS!MILLIONS!  145.3MILLIONS!      3.3MILLIONS!
# Casino Royale     315.0MILLIONS!MILLIONS!   85.0MILLIONS!      nanMILLIONS!

# %%
bond = pd.read_csv("/home/gabrielajachs/Downloads/pandas/jamesbond.csv", index_col = "Film")
bond.sort_index(inplace = True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
def good_movie(row):
    
    actor = row[1]
    budget = row[4]
    
    if actor == "Pierce Brosnan":
        return "The Best"
    elif actor == "Roger Moore" and budget > 40:
        return "Enjoyable"
    else:
        return "I have no clue"
    
bond.apply(good_movie, axis = "columns")
# Out:
# Film
# A View to a Kill                        Enjoyable
# Casino Royale                      I have no clue
# Casino Royale                      I have no clue
# Diamonds Are Forever               I have no clue
# Die Another Day                          The Best
# Dr. No                             I have no clue
# For Your Eyes Only                      Enjoyable
# From Russia with Love              I have no clue
# GoldenEye                                The Best
# Goldfinger                         I have no clue
# Licence to Kill                    I have no clue
# Live and Let Die                   I have no clue
# Moonraker                               Enjoyable
# Never Say Never Again              I have no clue
# Octopussy                               Enjoyable
# On Her Majesty's Secret Service    I have no clue
# Quantum of Solace                  I have no clue
# Skyfall                            I have no clue
# Spectre                            I have no clue
# ...

# %%
bond = pd.read_csv("/home/gabrielajachs/Downloads/pandas/jamesbond.csv", index_col = "Film")
bond.sort_index(inplace = True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
directors = bond["Director"]
directors.head(3)
# Out:
# Film
# A View to a Kill          John Glen
# Casino Royale       Martin Campbell
# Casino Royale            Ken Hughes
# Name: Director, dtype: object

# %%
directors["A View To Kill"] = "Mister John Glen"
# Out:
# <ipython-input-260-cd7359241530>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   directors["A View To Kill"] = "Mister John Glen"

# %%
directors.head(3)
# Out:
# Film
# A View to a Kill          John Glen
# Casino Royale       Martin Campbell
# Casino Royale            Ken Hughes
# Name: Director, dtype: object

# %%
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
bond = pd.read_csv("/home/gabrielajachs/Downloads/pandas/jamesbond.csv", index_col = "Film")
bond.sort_index(inplace = True)
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
directors = bond["Director"].copy()
directors.head(3)
# Out:
# Film
# A View to a Kill          John Glen
# Casino Royale       Martin Campbell
# Casino Royale            Ken Hughes
# Name: Director, dtype: object

# %%
directors["A View to a Kill"] = "Mister John Glen"

# %%
directors.head(3)
# Out:
# Film
# A View to a Kill    Mister John Glen
# Casino Royale        Martin Campbell
# Casino Royale             Ken Hughes
# Name: Director, dtype: object

# %%
bond.head(3)
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN
